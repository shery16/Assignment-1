# %%
import pandas as pd

# %%
df = pd.read_csv("compensation data.csv")

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.head(5)
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288

# %%
for i in df:
    print(type(i[5]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# experience_coding    float64
# python_user             bool
# r_user                  bool
# sql_user                bool
# most_used             object
# compensation           int64
# dtype: object

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df['experience_coding'] = df['experience_coding'].astype(float)
df['python_user'] = df['python_user'].astype(bool)
df['r_user'] = df['r_user'].astype(bool)
df['sql_user'] = df['sql_user'].astype(bool)
df['most_used'] = df['most_used'].replace('None', None)
df['compensation'] = df['compensation'].astype(float)

df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0          124267.0
# 1          236889.0
# 2           74321.0
# 3           62593.0
# ...

# %%
for value in df['compensation']:
    print(value)
# Out:
# 124267.0
# 236889.0
# 74321.0
# 62593.0
# 36288.0
# 61302.0
# 68984.0
# 18858.0
# 55418.0
# 614.0
# 70564.0
# 55525.0
# 61005.0
# 2846.0
# 21.0
# 14699.0
# 2110.0
# 620.0
# 73527.0
# 6992.0
# 22311.0
# 1377.0
# 69174.0
# 117636.0
# 65937.0
# 27856.0
# 903.0
# 50501.0
# 482.0
# 70407.0
# 8690.0
# 114648.0
# 73454.0
# 8075.0
# 59151.0
# 70112.0
# 70183.0
# 64502.0
# 2521.0
# 63616.0
# 59849.0
# 31516.0
# 18582.0
# 4187.0
# 64405.0
# 114807.0
# 632.0
# 61157.0
# 1194.0
# 28955.0
# 56553.0
# 75177.0
# 28009.0
# 67074.0
# 50059.0
# 7624.0
# 74321.0
# 671.0
# 837.0
# 2011.0
# 62937.0
# 685.0
# 41615.0
# 52572.0
# 51856.0
# 411.0
# 152.0
# 8181.0
# 2708.0
# 55041.0
# 68412.0
# 6141.0
# 3979.0
# 3760.0
# 57465.0
# 3864.0
# 488487.0
# 24393.0
# 68624.0
# 70796.0
# 236889.0
# 57861.0
# 21055.0
# 59167.0
# 55882.0
# 73802.0
# 21206.0
# 79803.0
# 73043.0
# 268191.0
# 14298.0
# 68805.0
# 56003.0
# 73664.0
# 434.0
# 52109.0
# 10284.0
# 43906.0
# 67971.0
# 58465.0
# 64488.0
# 7709.0
# 1957.0
# ...

# %%
python_user = df['python_user'].sum()
r_user = df['r_user'].sum()
sql_user = df['sql_user'].sum()

print(f"Python users: {python_user}")
print(f"R users: {r_user}")
print(f"SQL users: {sql_user}")
# Out:
# Python users: 21860
# R users: 5335
# SQL users: 10757

# %%
import pandas as pd

# Assuming your DataFrame is named df
# Iterate over each row and print the 'experience_coding' and 'compensation' columns
for index, row in df.iterrows():
    exp = row['experience_coding']
    comp = row['compensation']
    print(f"Experience: {exp}, Compensation: {comp}")
# Out:
# Experience: 6.1, Compensation: 124267.0
# Experience: 12.3, Compensation: 236889.0
# Experience: 2.2, Compensation: 74321.0
# Experience: 2.7, Compensation: 62593.0
# Experience: 1.2, Compensation: 36288.0
# Experience: 1.0, Compensation: 61302.0
# Experience: 1.8, Compensation: 68984.0
# Experience: 6.1, Compensation: 18858.0
# Experience: 4.5, Compensation: 55418.0
# Experience: 1.1, Compensation: 614.0
# Experience: 2.7, Compensation: 70564.0
# Experience: 0.93, Compensation: 55525.0
# Experience: 0.32, Compensation: 61005.0
# Experience: 9.9, Compensation: 2846.0
# Experience: 0.78, Compensation: 21.0
# Experience: 13.5, Compensation: 14699.0
# Experience: 26.5, Compensation: 2110.0
# Experience: 1.5, Compensation: 620.0
# Experience: 3.4, Compensation: 73527.0
# Experience: 0.6, Compensation: 6992.0
# Experience: 0.95, Compensation: 22311.0
# Experience: 4.6, Compensation: 1377.0
# Experience: 2.8, Compensation: 69174.0
# Experience: 28.2, Compensation: 117636.0
# ...

# %%
experience = df['experience_coding']
compensation = df['compensation']

experience
compensation
# Out:
# 0        124267.0
# 1        236889.0
# 2         74321.0
# 3         62593.0
# 4         36288.0
#            ...
# 25968     15800.0
# 25969     62456.0
# 25970       923.0
# 25971     60609.0
# 25972       493.0
# Name: compensation, Length: 25973, dtype: float64

# %%
compensation[:10]
# Out:
# 0    124267.0
# 1    236889.0
# 2     74321.0
# 3     62593.0
# 4     36288.0
# 5     61302.0
# 6     68984.0
# 7     18858.0
# 8     55418.0
# 9       614.0
# Name: compensation, dtype: float64

# %%
print(min(experience))   
print(max(experience))
# Out:
# 0.0
# 30.0

# %%
average_experience = sum(experience) / len(experience)
average_experience
# Out:
# 5.297231740653756

# %%
print(min(compensation))
print(max(compensation))
# Out:
# 0.0
# 1492951.0

# %%
average_compensation = sum(compensation) / len(compensation)
average_compensation
# Out:
# 53252.81696377007

# %%
def categorize_experience(years):
    if years < 5:
        return "< 5 Years"
    elif years < 10:
        return "5-10 Years"
    elif years < 15:
        return "10-15 Years"
    elif years < 20:
        return "15-20 Years"
    elif years < 25:
        return "20-25 Years"
    else:
        return "25+ Years"

df['experience_category'] = df['experience_coding'].apply(categorize_experience)

df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation experience_category
# 0          124267.0          5-10 Years
# 1          236889.0         10-15 Years
# ...

# %%
compensation_by_category = {
    "< 5 Years": [],
    "5-10 Years": [],
    "10-15 Years": [],
    "15-20 Years": [],
    "20-25 Years": [],
    "25+ Years": []
}

for category, group in df.groupby('experience_category'):
    compensation_by_category[category] = group['compensation'].tolist()

lessthan5 = compensation_by_category["< 5 Years"]
fiveto10 = compensation_by_category["5-10 Years"]
tento15 = compensation_by_category["10-15 Years"]
fifteento20 = compensation_by_category["15-20 Years"]
twentyto25 = compensation_by_category["20-25 Years"]
moretha25 = compensation_by_category["25+ Years"]

lessthan5
fiveto10
tento15
fifteento20
twentyto25
moretha25
# Out:
# [2110.0,
#  117636.0,
#  268191.0,
#  949.0,
#  85525.0,
#  1129.0,
#  6196.0,
#  79687.0,
#  61352.0,
#  124867.0,
#  30662.0,
#  64217.0,
#  279.0,
#  71650.0,
#  262267.0,
#  197702.0,
#  61608.0,
#  154850.0,
#  66467.0,
#  220415.0,
#  80095.0,
#  74891.0,
#  429315.0,
#  714555.0,
#  20426.0,
#  2030.0,
#  104484.0,
#  20134.0,
#  56617.0,
#  95918.0,
#  20696.0,
#  66962.0,
#  237978.0,
#  199761.0,
#  1605.0,
#  51024.0,
#  33396.0,
#  60604.0,
#  119802.0,
#  131.0,
#  30081.0,
#  87401.0,
#  121443.0,
#  127954.0,
#  99635.0,
#  42220.0,
#  42492.0,
#  121310.0,
#  26614.0,
#  121013.0,
#  118531.0,
#  25868.0,
#  228689.0,
#  54618.0,
#  213681.0,
#  4544.0,
#  2199.0,
#  91432.0,
#  110594.0,
#  239232.0,
#  59193.0,
#  24633.0,
#  45020.0,
#  54646.0,
#  306223.0,
#  10545.0,
#  112042.0,
#  37103.0,
#  91973.0,
#  103943.0,
#  36913.0,
#  18911.0,
#  25705.0,
#  5358.0,
#  70122.0,
#  293342.0,
#  153134.0,
#  260651.0,
#  60774.0,
#  63034.0,
#  42668.0,
#  116.0,
# ...

# %%
def categorize_experience(years):
    if years < 5:
        return "< 5 Years"
    elif years < 10:
        return "5-10 Years"
    elif years < 15:
        return "10-15 Years"
    elif years < 20:
        return "15-20 Years"
    elif years < 25:
        return "20-25 Years"
    else:
        return "25+ Years"

df['experience_category'] = df['experience_coding'].apply(categorize_experience)

average_compensation = df.groupby('experience_category')['compensation'].mean()

for category, avg_comp in average_compensation.items():
    print(f"{category}: {avg_comp}")
# Out:
# 10-15 Years: 80226.75581395348
# 15-20 Years: 75101.82694106642
# 20-25 Years: 103159.80432432433
# 25+ Years: 90444.98512221042
# 5-10 Years: 59312.82033470161
# < 5 Years: 45047.87484669119
